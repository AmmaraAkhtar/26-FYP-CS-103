# %%
import pandas as pd

# %%
df1= pd.read_csv("Art  Design.csv")

# %%
df1.head()
# Out:
#    Rank                                              Name  \
# 0     1                      Canva: Design, Photo & Video
# 1     2                                        Sketchbook
# 2     3                                      ibis Paint X
# 3     4                       Thumbnail Maker For YouTube
# 4     5  Glitter dress coloring and drawing book for Kids
#
#              Developer      Category    Size  Star Rating Reviews Downloads  \
# 0                Canva  Art & Design   27 MB          4.4     66L     10Cr+
# 1           Sketchbook  Art & Design  100 MB          4.2      4L      5Cr+
# 2            ibis inc.  Art & Design   27 MB          4.3     19L     10Cr+
# 3  Content Arcade Apps  Art & Design   13 MB          4.2      1L      50L+
# 4           BaramGames  Art & Design   56 MB          4.0     33T      1Cr+
#
#   Rated for
# 0        3+
# 1        3+
# 2        3+
# 3        3+
# 4        3+

# %%
df2= pd.read_csv("Auto  Vehicles.csv")

# %%
df2.head()
# Out:
#    Rank                                               Name  \
# 0     1                            RTO Vehicle Information
# 1     2                     Vahak: Book Online Truck, Load
# 2     3  CARS24® – Buy Used Cars Online, Sell Car in 1 ...
# 3     4                                     BlackBuck Boss
# 4     5                     CarDekho:New & Second Hand Car
#
#                                           Developer         Category   Size  \
# 0  Learn English In Hindi - Translator & Dictionary  Auto & Vehicles  21 MB
# 1         Most Trusted Transporters from All India.  Auto & Vehicles  17 MB
# 2                   CARS24 Services Private Limited  Auto & Vehicles  33 MB
# 3                                         BlackBuck  Auto & Vehicles  39 MB
# 4                         Girnar Software Pvt. Ltd.  Auto & Vehicles  18 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.5      1L      1Cr+        3+
# 1          3.8      3T      10L+        3+
# ...

# %%
df3= pd.read_csv("Beauty.csv")

# %%
df3.head()
# Out:
#    Rank                                               Name          Developer  \
# 0     1                       Dress Up Royal Princess Doll         winkypinky
# 1     2           Beauty Camera : You Makeover Plus Selfie  SB Gallery Studio
# 2     3        SUGAR Cosmetics: Buy Beauty Products Online    SUGAR Cosmetics
# 3     4                        Men Hair style photo Editor         kobecodder
# 4     5  Beauty Makeup Editor: Beauty Camera, Photo Editor    Lyrebird Studio
#
#   Category   Size  Star Rating Reviews Downloads Rated for
# 0   Beauty  42 MB          3.7     11T      10L+        3+
# 1   Beauty  16 MB          3.5     22T      1Cr+        3+
# 2   Beauty  13 MB          4.5     42T      10L+        3+
# 3   Beauty  13 MB          3.7      2T      10L+        3+
# 4   Beauty  68 MB          3.6      2L      1Cr+        3+

# %%
df5= pd.read_csv("Books  Reference.csv")

# %%
df5.head()
# Out:
#    Rank                                       Name              Developer  \
# 0     1               Pratilipi - World of Stories              Pratilipi
# 1     2  motesFF Challenge - All motes with dances           vijay sharma
# 2     3                 How to Get diamonds in FFF  Ultra HD Video Player
# 3     4              Amazon Kindle - eBooks & more      Amazon Mobile LLC
# 4     5                          Google Play Books             Google LLC
#
#             Category    Size  Star Rating Reviews Downloads Rated for
# 0  Books & Reference   14 MB          4.5      2L      1Cr+       12+
# 1  Books & Reference   20 MB          3.8      3T      10L+        3+
# 2  Books & Reference   11 MB          4.1     32T      1Cr+        3+
# 3  Books & Reference   56 MB          4.6     22L     10Cr+       12+
# 4  Books & Reference  9.7 MB          4.1      1M       1B+       12+

# %%
df6= pd.read_csv("Business.csv")

# %%
df6.head()
# Out:
#    Rank                            Name              Developer  Category  \
# 0     1             ZOOM Cloud Meetings                zoom.us  Business
# 1     2                     Google Meet             Google LLC  Business
# 2     3  apna: Job Search, Alerts India                   apna  Business
# 3     4                 Microsoft Teams  Microsoft Corporation  Business
# 4     5    Adobe Scan: PDF Scanner, OCR                  Adobe  Business
#
#     Size  Star Rating Reviews Downloads Rated for
# 0  41 MB          4.0      3M     500M+        3+
# 1  20 MB          4.1      2M     100M+        3+
# 2  25 MB          4.6      2L      1Cr+       12+
# 3  64 MB          4.3      4M     100M+        3+
# 4  28 MB          4.6      1M      50M+        3+

# %%
df7 = pd.read_csv("Comics.csv")

# %%
df7.head()
# Out:
#    Rank                                              Name  \
# 0     1                    Free Comics - Pratilipi Comics
# 1     2                     BILIBILI COMICS - Read Comics
# 2     3                Girls Live Video Call – Video Chat
# 3     4                                           WEBTOON
# 4     5  Picasso : Live Tv show, Movies and Cricket Guide
#
#                Developer Category    Size  Star Rating Reviews Downloads  \
# 0              Pratilipi   Comics  6.5 MB          4.3     39T      50L+
# 1        Bilibili Comics   Comics   38 MB          4.2     63T      50L+
# 2        Shree Intersoft   Comics   16 MB          3.5     743       1L+
# 3  WEBTOON ENTERTAINMENT   Comics   23 MB          4.8     23L      5Cr+
# 4         Live Life 2021   Comics  6.2 MB          3.0      1T       1L+
#
#   Rated for
# 0       12+
# 1       12+
# 2       18+
# 3       12+
# 4        3+

# %%
df8 = pd.read_csv("EDucation.csv")

# %%
df8.head()
# Out:
#    Rank                            Name               Developer   Category  \
# 0     1       BYJU'S – The Learning App                  BYJU'S  Education
# 1     2          Brainly — Solve Doubts                 Brainly  Education
# 2     3    Duolingo: Learn English Free                Duolingo  Education
# 3     4           Unacademy Learner App               Unacademy  Education
# 4     5  Teachmint - Live Classroom App  Teachmint Technologies  Education
#
#     Size  Star Rating Reviews Downloads Rated for
# 0  76 MB          4.2     17L     10Cr+        3+
# 1  17 MB          4.3     21L     10Cr+        3+
# 2  21 MB          4.5     1Cr     10Cr+        3+
# 3  45 MB          4.0      9L      5Cr+        3+
# 4  19 MB          4.2      1L      1Cr+        3+

# %%
df9 = pd.read_csv("Entertainment.csv")

# %%
df9.head()
# Out:
#    Rank                                      Name              Developer  \
# 0     1                        Amazon Prime Video      Amazon Mobile LLC
# 1     2            ZEE5:Movies, Web Series & more      Z5X Global FZ LLC
# 2     3                                   Hotstar           Novi Digital
# 3     4  Zili - Short Video App for India | Funny                   Zili
# 4     5                                     JioTV  Jio Platforms Limited
#
#         Category   Size  Star Rating Reviews Downloads Rated for
# 0  Entertainment  28 MB          4.3      3M     100M+       12+
# 1  Entertainment  21 MB          3.5     12L     10Cr+       12+
# 2  Entertainment  23 MB          4.2     10M     500M+       12+
# 3  Entertainment  25 MB          4.0      8L     10Cr+       12+
# 4  Entertainment  16 MB          4.0     35L     10Cr+        3+

# %%
df10 = pd.read_csv("Events.csv")

# %%
df10.head()
# Out:
#    Rank                            Name                          Developer  \
# 0     1  Invitation maker & Card design                   Greetings Island
# 1     2                      Tournafest  Tournafest Gaming Private Limited
# 2     3      Video Invitation Maker App                   VideoInvites.net
# 3     4       Wedding Card Maker Indian             Hope & Courage Company
# 4     5                       Kiko Live                          Kiko Live
#
#   Category    Size  Star Rating Reviews Downloads Rated for
# 0   Events   26 MB          4.6     89T      1Cr+        3+
# 1   Events   21 MB          4.2     573      50T+        3+
# 2   Events  4.6 MB          3.8      1T       5L+        3+
# 3   Events  7.5 MB          4.6      1T       1L+        3+
# 4   Events   58 MB          4.1      1T       1L+        3+

# %%
df11 = pd.read_csv("Finance.csv")

# %%
df11.head()
# Out:
#    Rank                                               Name  \
# 0     1      PhonePe: UPI, Recharge, Investment, Insurance
# 1     2  Paytm -UPI, Money Transfer, Recharge, Bill Pay...
# 2     3                     Google Pay: Secure UPI payment
# 3     4                     CoinDCX:Bitcoin Investment App
# 4     5                     Navi: Loans & Health Insurance
#
#                            Developer Category   Size  Star Rating Reviews  \
# 0                            PhonePe  Finance  35 MB          4.3     78L
# 1  Paytm - One97 Communications Ltd.  Finance  31 MB          4.6     1Cr
# 2                         Google LLC  Finance  20 MB          4.2     71L
# 3                   CoinDCX Official  Finance  22 MB          3.6      2L
# 4                           navi.com  Finance  24 MB          3.9      1L
#
#   Downloads Rated for
# 0     10Cr+        3+
# 1     10Cr+        3+
# 2     50Cr+        3+
# 3      1Cr+        3+
# 4      1Cr+        3+

# %%
df12 = pd.read_csv("Food  Drink.csv")

# %%
df12.head()
# Out:
#    Rank                                               Name  \
# 0     1                     Zomato: Food Delivery & Dining
# 1     2                      Swiggy : Food Delivery & More
# 2     3          Domino's Pizza - Online Food Delivery App
# 3     4                         blinkit (formerly grofers)
# 4     5  Country Delight: Milk Delivery, Vegetable, Gro...
#
#                Developer      Category   Size  Star Rating Reviews Downloads  \
# 0                 Zomato  Food & Drink  21 MB          4.1     60L     10Cr+
# 1                 Swiggy  Food & Drink  33 MB          4.0      2M     100M+
# 2     Jubilant Foodworks  Food & Drink  11 MB          4.6    741K      10M+
# 3  Grofers India Pvt Ltd  Food & Drink  20 MB          4.1      6L      1Cr+
# 4        Country Delight  Food & Drink  17 MB          4.7     34T      50L+
#
#   Rated for
# 0        3+
# 1        3+
# 2        3+
# 3        3+
# 4       12+

# %%
df13 = pd.read_csv("Health  Fitness.csv")

# %%
df13.head()
# Out:
#    Rank                           Name  \
# 0     1  HealthifyMe - Calorie Counter
# 1     2     Skin-scan: Hand Protection
# 2     3                   Aarogya Setu
# 3     4                 Mylab CoviSelf
# 4     5          Co-WIN Vaccinator App
#
#                                           Developer          Category    Size  \
# 0  HealthifyMe (Calorie Counter, Weight Loss Coach)  Health & Fitness   44 MB
# 1                                   3B Gamse Studio  Health & Fitness   49 MB
# 2                      National Informatics Centre.  Health & Fitness  3.1 MB
# 3                         Mylab Discovery Solutions  Health & Fitness   26 MB
# 4                      National Health Portal-MoHFW  Health & Fitness   11 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.4      3L      1Cr+        3+
# 1          4.3      2T       5L+        3+
# 2          3.8     16L     10Cr+        3+
# 3          2.3      1T       5L+        3+
# ...

# %%
df14 = pd.read_csv("Health  Fitness.csv")

# %%
df14.head()
# Out:
#    Rank                           Name  \
# 0     1  HealthifyMe - Calorie Counter
# 1     2     Skin-scan: Hand Protection
# 2     3                   Aarogya Setu
# 3     4                 Mylab CoviSelf
# 4     5          Co-WIN Vaccinator App
#
#                                           Developer          Category    Size  \
# 0  HealthifyMe (Calorie Counter, Weight Loss Coach)  Health & Fitness   44 MB
# 1                                   3B Gamse Studio  Health & Fitness   49 MB
# 2                      National Informatics Centre.  Health & Fitness  3.1 MB
# 3                         Mylab Discovery Solutions  Health & Fitness   26 MB
# 4                      National Health Portal-MoHFW  Health & Fitness   11 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.4      3L      1Cr+        3+
# 1          4.3      2T       5L+        3+
# 2          3.8     16L     10Cr+        3+
# 3          2.3      1T       5L+        3+
# ...

# %%
df15 = pd.read_csv("Libraries  Demo.csv")

# %%
df15.head()
# Out:
#    Rank                          Name                           Developer  \
# 0     1                         Guide                             Tubejet
# 1     2  MX Player Codec (ARMv7 NEON)  MX Media (formerly J2 Interactive)
# 2     3   Tap Tap app Apk Games Guide                         Kitty Pitty
# 3     4                      V380 Pro                          macrovideo
# 4     5                   MFS100 Test        Mantra Softech India Pvt Ltd
#
#            Category    Size  Star Rating Reviews Downloads Rated for
# 0  Libraries & Demo   11 MB          3.9     442       1L+        3+
# 1  Libraries & Demo  8.1 MB          3.8      4L      5Cr+        3+
# 2  Libraries & Demo   13 MB          3.6     166      10T+        3+
# 3  Libraries & Demo   62 MB          3.9     48T      1Cr+        3+
# 4  Libraries & Demo  3.8 MB          4.2      1T      10L+        3+

# %%
df16 = pd.read_csv("Lifestyle.csv")

# %%
df16.head()
# Out:
#    Rank                                       Name  \
# 0     1                                  Pinterest
# 1     2                                 ECO Mitram
# 2     3             magicpin: shop at local stores
# 3     4  Trell - Lifestyle Videos and Shopping App
# 4     5                                Google Home
#
#                                            Developer   Category    Size  \
# 0                                          Pinterest  Lifestyle   25 MB
# 1                                        Ready Bytes  Lifestyle  7.7 MB
# 2  magicpin: cashback / home delivery on local re...  Lifestyle   25 MB
# 3                                  Trell Experiences  Lifestyle   24 MB
# 4                                         Google LLC  Lifestyle   19 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.4     87L     50Cr+       12+
# 1          4.1      1T       5L+        3+
# 2          4.1      1L      50L+        3+
# 3          4.4      1L      1Cr+       12+
# ...

# %%
df17 = pd.read_csv("Maps  Navigation.csv")

# %%
df17.head()
# Out:
#    Rank                                  Name                Developer  \
# 0     1                            what3words               what3words
# 1     2        Ola, Safe and affordable rides                      ola
# 2     3               Rapido Bike Taxi & Auto         Rapido Bike Taxi
# 3     4  CarInfo: RTO Vehicle Information App                 Car Info
# 4     5          Uber - Easy affordable trips  Uber Technologies, Inc.
#
#             Category   Size  Star Rating Reviews Downloads Rated for
# 0  Maps & Navigation  43 MB          4.0     26T      1Cr+        3+
# 1  Maps & Navigation  31 MB          4.3     19L     10Cr+        3+
# 2  Maps & Navigation  18 MB          4.0      7L      1Cr+        3+
# 3  Maps & Navigation  15 MB          4.5      7L      1Cr+        3+
# 4  Maps & Navigation  64 MB          4.2     94L     50Cr+        3+

# %%
df18 = pd.read_csv("Medical.csv")

# %%
df18.head()
# Out:
#    Rank                                               Name  \
# 0     1                         PharmEasy - Healthcare App
# 1     2                     TATA 1mg Online Healthcare App
# 2     3                        Netmeds - India Ki Pharmacy
# 3     4   Apollo 247 - Online Doctor & Apollo Pharmacy App
# 4     5  Phable: Health Tracker for Diabetes & Hyperten...
#
#                                        Developer Category   Size  Star Rating  \
# 0               Axelia Solutions Private Limited  Medical  18 MB          4.6
# 1  Tata 1MG Healthcare Solutions Private Limited  Medical  12 MB          4.5
# 2                    Netmeds Marketplace Limited  Medical  17 MB          4.3
# 3            Apollo Hospitals Enterprise Limited  Medical  37 MB          4.2
# 4                                     PhableCare  Medical  51 MB          3.6
#
#   Reviews Downloads Rated for
# 0      5L      1Cr+        3+
# 1      4L      1Cr+        3+
# 2      3L      1Cr+        3+
# ...

# %%
df19 = pd.read_csv("Music  Audio.csv")

# %%
df19.head()
# Out:
#    Rank                            Name            Developer       Category  \
# 0     1  Gaana Music : Songs & Podcasts      Gamma Gaana Ltd  Music & Audio
# 1     2  Wynk Music -Songs & HelloTunes               Airtel  Music & Audio
# 2     3     JioSaavn - Music & Podcasts  Saavn Media Limited  Music & Audio
# 3     4  Pocket FM: Audiobook & Podcast            Pocket FM  Music & Audio
# 4     5    Resso Music - Songs & Lyrics      Moon Video Inc.  Music & Audio
#
#     Size  Star Rating Reviews Downloads Rated for
# 0  31 MB          4.5     45L     10Cr+       12+
# 1  21 MB          4.3     38L     10Cr+        3+
# 2  23 MB          4.2     39L     10Cr+        3+
# 3  16 MB          4.2      7L      1Cr+       12+
# 4  48 MB          4.6     14L     10Cr+       12+

# %%
df20 = pd.read_csv("News  Magazines.csv")

# %%
df20.head()
# Out:
#    Rank                                               Name  \
# 0     1  Dailyhunt - Local & National News, Videos, Cri...
# 1     2  Dainik Bhaskar:Hindi News Paper App, ePaper, V...
# 2     3                      Aaj Tak Live - Hindi News App
# 3     4   Narendra Modi - Latest News, Videos and Speeches
# 4     5                          Koo: Connect with People!
#
#                   Developer          Category    Size  Star Rating Reviews  \
# 0           Eterno Infotech  News & Magazines   13 MB          4.4     16L
# 1      Dainik Bhaskar Group  News & Magazines  8.3 MB          4.3      3L
# 2  TV Today Network Limited  News & Magazines   14 MB          4.0      2L
# 3           NarendraModi.in  News & Magazines   47 MB          4.4      2L
# 4                 Koo India  News & Magazines   16 MB          4.5      2L
#
#   Downloads Rated for
# 0     10Cr+       12+
# 1      1Cr+        3+
# 2      5Cr+        3+
# 3      1Cr+        3+
# 4      1Cr+       12+

# %%
df21 = pd.read_csv("Parenting.csv")

# %%
df21.head()
# Out:
#    Rank                                              Name  \
# 0     1  Indian Pregnancy, Parenting Tips & Baby Products
# 1     2                    Mylo Pregnancy & Parenting App
# 2     3                  LastLog-Last Seen Online Tracker
# 3     4     Pregnancy + | tracker app, week by week in 3D
# 4     5    Top Parent - New Ways of Learning And Teaching
#
#                                            Developer   Category    Size  \
# 0  Indian Pregnancy Parenting tips, Baby products...  Parenting   19 MB
# 1    Mylo - Indian Pregnancy Tracker & Baby Care App  Parenting   16 MB
# 2                                       LastLog Inc.  Parenting   13 MB
# 3                         Philips Digital UK Limited  Parenting   50 MB
# 4                                          Humanitus  Parenting  2.6 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.6     80T      1Cr+       12+
# 1          4.6     70T      10L+        3+
# 2          4.1      8T       1L+        3+
# ...

# %%
df22 = pd.read_csv("Personalisation.csv")

# %%
df22.head()
# Out:
#    Rank                                          Name             Developer  \
# 0     1  iFonts - highlights cover, fonts, wallpapers         Onbillion Ltd
# 1     2                 ZEDGE™ Wallpapers & Ringtones                 Zedge
# 2     3                           Name Ringtone Maker  DoubleRun Technology
# 3     4                 MobCup Ringtones & Wallpapers                MobCup
# 4     5                                Fonts Keyboard        Fonts Keyboard
#
#           Category    Size  Star Rating Reviews Downloads Rated for
# 0  Personalisation   19 MB          2.9      6T      1Cr+        3+
# 1  Personalisation   28 MB          4.3     95L     10Cr+       12+
# 2  Personalisation  5.5 MB          3.8      8T      1Cr+        3+
# 3  Personalisation   13 MB          4.3     21T      50L+       12+
# 4  Personalisation  5.1 MB          4.3      8L      5Cr+        3+

# %%
df23 = pd.read_csv("Photography.csv")

# %%
df23.head()
# Out:
#    Rank                                           Name            Developer  \
# 0     1                  Video Editor & Maker - InShot  InShot Video Editor
# 1     2                            EPIK - Photo Editor           SNOW, Inc.
# 2     3  Instore: Story Saver, Story, Video Downloader    Apps for Creators
# 3     4                 Picsart Photo and Video Editor        PicsArt, Inc.
# 4     5                                       Snapseed           Google LLC
#
#       Category   Size  Star Rating Reviews Downloads Rated for
# 0  Photography  53 MB          4.6     1Cr     10Cr+        3+
# 1  Photography  83 MB          4.2     30T      50L+       12+
# 2  Photography  24 MB          4.3      4L      1Cr+        3+
# 3  Photography  43 MB          4.2     1Cr     50Cr+       12+
# 4  Photography  24 MB          4.3     14L     10Cr+        3+

# %%
df24 = pd.read_csv("Productivity.csv")

# %%
df24.head()
# Out:
#    Rank                                            Name  \
# 0     1                       MyJio: For Everything Jio
# 1     2  Airtel Thanks – Recharge, Bill Pay, UPI & Bank
# 2     3                  Share Karo: Transfer, Share it
# 3     4                    Junk Smasher - Phone Cleaner
# 4     5                  Global- Fast VPN Proxy Servers
#
#                Developer      Category   Size  Star Rating Reviews Downloads  \
# 0  Jio Platforms Limited  Productivity  42 MB          4.3     1Cr     10Cr+
# 1                 Airtel  Productivity  30 MB          4.3     57L     10Cr+
# 2         ShareKaro Team  Productivity  12 MB          4.3     53T      1Cr+
# 3       InnoDev Pro Team  Productivity  11 MB          4.1     87T      1Cr+
# 4             BaronBaron  Productivity  10 MB          3.4      3T      50L+
#
#   Rated for
# 0        3+
# 1        3+
# 2        3+
# 3        3+
# 4        3+

# %%
df25 = pd.read_csv("Shopping.csv")

# %%
df25.head()
# Out:
#    Rank                            Name          Developer  Category   Size  \
# 0     1     Meesho: Online Shopping App             Meesho  Shopping  14 MB
# 1     2         Shopee: Online Shopping             Shopee  Shopping  68 MB
# 2     3    Flipkart Online Shopping App           Flipkart  Shopping  18 MB
# 3     4  Shopsy Shopping App - Flipkart             Shopsy  Shopping  17 MB
# 4     5       Amazon India - Shop & Pay  Amazon Mobile LLC  Shopping  57 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.4     15L     10Cr+        3+
# 1          4.2     86T      1Cr+        3+
# 2          4.3     2Cr     10Cr+       12+
# 3          4.3      3L      1Cr+        3+
# 4          4.2     79L     10Cr+        3+

# %%
df26 = pd.read_csv("Social.csv")

# %%
df26.head()
# Out:
#    Rank                        Name                      Developer Category  \
# 0     1                   Instagram                      Instagram   Social
# 1     2  Chingari - powered by GARI                       Chingari   Social
# 2     3                    Facebook           Meta Platforms, Inc.   Social
# 3     4  Rizzle - Short Video Maker  Silverlabs Technologies, Inc.   Social
# 4     5      Josh: Short Videos App              Ver Se Innovation   Social
#
#     Size  Star Rating Reviews Downloads Rated for
# 0  40 MB          4.3    13Cr    100Cr+       12+
# 1  56 MB          3.8      4L      5Cr+       12+
# 2  51 MB          4.1    12Cr    500Cr+       12+
# 3  43 MB          4.3      2L      1Cr+       12+
# 4  38 MB          4.1      6L     10Cr+       12+

# %%
df27 = pd.read_csv("Sports.csv")

# %%
df27.head()
# Out:
#    Rank                                               Name  \
# 0     1                     Rooter: Watch Gaming & Esports
# 1     2                                             Da Fit
# 2     3                     Live Cricket & Scores: FanCode
# 3     4      Cricket Scoring App | Live Score - CricHeroes
# 4     5  iMPL Game - Play Games & Earn Money From iMPL ...
#
#                              Developer Category    Size  Star Rating Reviews  \
# 0                        Rooter Sports   Sports   26 MB          4.3      3L
# 1                               CRREPA   Sports  8.5 MB          3.9     86T
# 2  Sporta Technologies Private Limited   Sports   27 MB          4.1      1L
# 3                 CricHeroes Pvt. Ltd.   Sports   19 MB          4.6     97T
# 4                            iMPL Game   Sports  8.6 MB          3.7      2T
#
#   Downloads Rated for
# 0      1Cr+       12+
# 1      1Cr+        3+
# 2      1Cr+       12+
# 3      50L+        3+
# 4      10L+        3+

# %%
df28 = pd.read_csv("Tools.csv")

# %%
df28.head()
# Out:
#    Rank                            Name  \
# 0     1                    speedfiy Pro
# 1     2            All Video Downloader
# 2     3         ShareKaro: File Sharing
# 3     4  Noizz: video editor with music
# 4     5                        speedfiy
#
#                                  Developer Category    Size  Star Rating  \
# 0                  PRIME DIGITAL PTE. LTD.    Tools   13 MB          4.4
# 1  All Video Downloader & Story Saver Apps    Tools  7.2 MB          4.2
# 2                           ShareKaro Team    Tools   14 MB          4.4
# 3                               Noizz Team    Tools   37 MB          4.0
# 4                  PRIME DIGITAL PTE. LTD.    Tools   12 MB          4.4
#
#   Reviews Downloads Rated for
# 0     31K       5M+        3+
# 1     49T      1Cr+        3+
# 2      2L      5Cr+        3+
# 3      5L     10Cr+       12+
# 4     45T      1Cr+        3+

# %%
df29 = pd.read_csv("Travel  Local.csv")

# %%
df29.head()
# Out:
#    Rank                          Name  \
# 0     1             Where is my Train
# 1     2  Train Status Ticket Book PNR
# 2     3            IRCTC Rail Connect
# 3     4    ConfirmTkt - Train Booking
# 4     5                  Google Earth
#
#                                           Developer        Category    Size  \
# 0                   Sigmoid Labs and its Affiliates  Travel & Local   10 MB
# 1  ixigo - IRCTC Authorised Partner, Flight Tickets  Travel & Local   18 MB
# 2                                    IRCTC Official  Travel & Local   16 MB
# 3             ConfirmTkt - IRCTC Authorised Partner  Travel & Local   14 MB
# 4                                        Google LLC  Travel & Local  8.6 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.4     29L     10Cr+        3+
# 1          4.4     19L     10Cr+        3+
# 2          4.0     22L      5Cr+        3+
# 3          4.6      4L      1Cr+        3+
# 4          4.4     28L     10Cr+        3+

# %%
df30 = pd.read_csv("Video Players  Editors.csv")

# %%
df30.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 1     2  mAst: Music Status Video Maker                           Mast Team
# 2     3  Mivita - Face Swap Video Maker                               vakie
# 3     4  PLAYit-All in One Video Player         PLAYIT TECHNOLOGY PTE. LTD.
# 4     5  Mivi:Music&Lyrical Video Maker                  Music Video Studio
#
#                   Category   Size  Star Rating Reviews Downloads Rated for
# 0  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 1  Video Players & Editors  65 MB          4.3      2L      5Cr+        3+
# 2  Video Players & Editors  64 MB          3.2      6T      10L+        3+
# 3  Video Players & Editors  14 MB          4.5     35L     10Cr+        3+
# 4  Video Players & Editors  44 MB          4.3      1L      1Cr+        3+

# %%
df = pd.concat([df2, df3,  df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30], ignore_index=True)

# %%
df.head()
# Out:
#    Rank                                               Name  \
# 0     1                            RTO Vehicle Information
# 1     2                     Vahak: Book Online Truck, Load
# 2     3  CARS24® – Buy Used Cars Online, Sell Car in 1 ...
# 3     4                                     BlackBuck Boss
# 4     5                     CarDekho:New & Second Hand Car
#
#                                           Developer         Category   Size  \
# 0  Learn English In Hindi - Translator & Dictionary  Auto & Vehicles  21 MB
# 1         Most Trusted Transporters from All India.  Auto & Vehicles  17 MB
# 2                   CARS24 Services Private Limited  Auto & Vehicles  33 MB
# 3                                         BlackBuck  Auto & Vehicles  39 MB
# 4                         Girnar Software Pvt. Ltd.  Auto & Vehicles  18 MB
#
#    Star Rating Reviews Downloads Rated for
# 0          4.5      1L      1Cr+        3+
# 1          3.8      3T      10L+        3+
# ...

# %%
df.shape
# Out:
# (13928, 9)

# %%
df.tail()
# Out:
#        Rank                                         Name  \
# 13923   496  Video Hider - Photo Vault, Video Downloader
# 13924   497                             Video Downloader
# 13925   498                  Video Maker with Music 2022
# 13926   499                  Private Photo, Video Locker
# 13927   500                                 Video player
#
#                                  Developer                 Category    Size  \
# 13923         Photo Editor & Collage Maker  Video Players & Editors   11 MB
# 13924                               Vid Dl  Video Players & Editors   11 MB
# 13925  Photo Slideshow & Photo Video Maker  Video Players & Editors   16 MB
# 13926                        Kohinoor Apps  Video Players & Editors  9.2 MB
# 13927                              atbcstd  Video Players & Editors   23 MB
#
#        Star Rating Reviews Downloads Rated for
# 13923          4.1     32T      50L+        3+
# 13924          3.1     291       1L+        3+
# ...

# %%
df.to_csv('app_data.csv')
